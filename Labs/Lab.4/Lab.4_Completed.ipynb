# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %%
Name: Umayer Kabir
UTA ID: 1002173764

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
# Cell 0 - Setup
# Just imports we’ll use later.

import math
from abc import ABC, abstractmethod

# %%
# Q1 - Counter that increments up to a max, prints an error if it goes past, and can reset.

class Counter:
    def __init__(self, max_value, start=0):
        self.max_value = max_value
        self.value = start

    def increment(self, amount=1):
        if self.value + amount > self.max_value:
            print("Error: tried to increment past the maximum value.")
            return
        self.value += amount

    def reset(self, start=0):
        self.value = start

# %%
# Test Cell

c = Counter(3)
print("start:", c.value)
c.increment()
print("after +1:", c.value)
c.increment(5)  # should error
print("after too big:", c.value)
c.reset()
print("after reset:", c.value)
# Out:
# start: 0
# after +1: 1
# Error: tried to increment past the maximum value.
# after too big: 1
# after reset: 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
# Q2 - Same counter, but with private data and some extra check functions.

class PrivateCounter:
    def __init__(self, max_value, start=0):
        self.__max_value = max_value
        self.__value = start

    def increment(self, amount=1):
        if self.__value + amount > self.__max_value:
            print("Error: tried to increment past the maximum value.")
            return
        self.__value += amount

    def reset(self, start=0):
        self.__value = start

    def get_value(self):
        return self.__value

    def get_max(self):
        return self.__max_value

    def is_at_max(self):
        return self.__value == self.__max_value

# %%
# Test Cell

pc = PrivateCounter(3)
print("value:", pc.get_value(), "max:", pc.get_max(), "at max?", pc.is_at_max())
pc.increment()
pc.increment()
pc.increment()
print("value:", pc.get_value(), "at max?", pc.is_at_max())
pc.increment()  # should error
# Out:
# value: 0 max: 3 at max? False
# value: 3 at max? True
# Error: tried to increment past the maximum value.

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
# Q3 - Rectangle with private members, area/perimeter, and getters.

class RectangleBasic:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    def get_length(self): return self.__length
    def get_width(self):  return self.__width
    def get_x(self):      return self.__x
    def get_y(self):      return self.__y

# %%
# Test Cell

rb = RectangleBasic(4, 3, 0, 0)
print("area:", rb.area())
print("perimeter:", rb.perimeter())
print("x,y:", rb.get_x(), rb.get_y())
# Out:
# area: 12
# perimeter: 14
# x,y: 0 0

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
# Q4 - Circle with private members, area/perimeter, and getters.

class CircleBasic:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * (self.__radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self): return self.__radius
    def get_x(self):      return self.__x
    def get_y(self):      return self.__y

# %%
# Test Cell

cb = CircleBasic(5, 2, 2)
print("area:", cb.area())
print("perimeter:", cb.perimeter())
print("center:", cb.get_x(), cb.get_y())
# Out:
# area: 78.53981633974483
# perimeter: 31.41592653589793
# center: 2 2

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
# Q5 - Base class with abstract methods, and Rectangle/Circle inherit from it.

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)

    # getters (handy later)
    def get_length(self): return self.__length
    def get_width(self):  return self.__width
    def get_x(self):      return self.__x
    def get_y(self):      return self.__y


class Circle(Shape):
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y

    def area(self):
        return math.pi * (self.__radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.__radius

    def get_radius(self): return self.__radius
    def get_x(self):      return self.__x
    def get_y(self):      return self.__y

# %%
# Test Cell

rect = Rectangle(4, 3, 0, 0)
circle = Circle(5, 2, 2)

print("Rectangle is Shape?", isinstance(rect, Shape))
print("Circle is Shape?", isinstance(circle, Shape))

print("rect area:", rect.area(), "perim:", rect.perimeter())
print("circle area:", circle.area(), "perim:", circle.perimeter())
# Out:
# Rectangle is Shape? True
# Circle is Shape? True
# rect area: 12 perim: 14
# circle area: 78.53981633974483 perim: 31.41592653589793

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
# Q6 - Triangle class similar idea to the others.
# I’m using base/height and assuming an isosceles triangle for perimeter.

class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.__base = base
        self.__height = height
        self.__x = x
        self.__y = y

    def area(self):
        return 0.5 * self.__base * self.__height

    def perimeter(self):
        side = math.sqrt((self.__base / 2) ** 2 + self.__height ** 2)
        return self.__base + 2 * side

    def get_base(self):   return self.__base
    def get_height(self): return self.__height
    def get_x(self):      return self.__x
    def get_y(self):      return self.__y

# %%
# Test Cell

tri = Triangle(6, 4, 0, 0)
print("Triangle is Shape?", isinstance(tri, Shape))
print("tri area:", tri.area())
print("tri perim:", tri.perimeter())
# Out:
# Triangle is Shape? True
# tri area: 12.0
# tri perim: 16.0

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
# Q7 - Add perimeter_points() to the base class.
# For now this is a simple placeholder: up to 16 (x,y) points.

def _shape_perimeter_points(self):
    pts = []
    for i in range(16):
        pts.append((i, i))
    return pts

Shape.perimeter_points = _shape_perimeter_points

# %%
# Test Cell

rect = Rectangle(4, 3, 0, 0)
pts = rect.perimeter_points()
print("num points:", len(pts))
print("first few:", pts[:5])
print("<= 16?", len(pts) <= 16)
# Out:
# num points: 16
# first few: [(0, 0), (1, 1), (2, 2), (3, 3), (4, 4)]
# <= 16? True

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
# Q8 - Add contains(x,y). Since Shape was already created, we attach an abstract-like placeholder,
# and then we implement real contains() on each concrete class.

def _shape_contains(self, x, y):
    raise NotImplementedError("contains() not implemented for this shape.")

Shape.contains = _shape_contains


def _rect_contains(self, x, y):
    return (self.get_x() <= x <= self.get_x() + self.get_length() and
            self.get_y() <= y <= self.get_y() + self.get_width())

Rectangle.contains = _rect_contains


def _circle_contains(self, x, y):
    dx = x - self.get_x()
    dy = y - self.get_y()
    return (dx*dx + dy*dy) <= (self.get_radius() ** 2)

Circle.contains = _circle_contains


def _tri_contains(self, x, y):
    # simple bounding check (lab-level)
    return (self.get_x() <= x <= self.get_x() + self.get_base() and
            self.get_y() <= y <= self.get_y() + self.get_height())

Triangle.contains = _tri_contains

# %%
# Test Cell

rect = Rectangle(4, 3, 0, 0)
circle = Circle(2, 5, 5)
tri = Triangle(4, 3, 0, 0)

print("rect contains (1,1):", rect.contains(1, 1))
print("rect contains (6,2):", rect.contains(6, 2))

print("circle contains (5,5):", circle.contains(5, 5))
print("circle contains (9,5):", circle.contains(9, 5))

print("tri contains (2,1):", tri.contains(2, 1))
print("tri contains (5,5):", tri.contains(5, 5))
# Out:
# rect contains (1,1): True
# rect contains (6,2): False
# circle contains (5,5): True
# circle contains (9,5): False
# tri contains (2,1): True
# tri contains (5,5): False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
# Q9 - overlaps(other): simple check using perimeter points + contains.

def _shape_overlaps(self, other):
    for (x, y) in self.perimeter_points():
        if other.contains(x, y):
            return True
    for (x, y) in other.perimeter_points():
        if self.contains(x, y):
            return True
    return False

Shape.overlaps = _shape_overlaps

# %%
# Test Cell

rect1 = Rectangle(6, 4, 0, 0)
circle1 = Circle(2, 3, 2)

rect2 = Rectangle(4, 3, 0, 0)
circle2 = Circle(1, 50, 50)

print("rect1 overlaps circle1?:", rect1.overlaps(circle1))
print("rect2 overlaps circle2?:", rect2.overlaps(circle2))
# Out:
# rect1 overlaps circle1?: True
# rect2 overlaps circle2?: True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
# %%writefile paint.py
# Q10 - paint.py module

import math

# Base Shape class (copied from earlier work)
class Shape:
    def area(self):
        raise NotImplementedError("Area method not implemented")

    def perimeter(self):
        raise NotImplementedError("Perimeter method not implemented")

    def perimeter_points(self):
        # Simple placeholder points (up to 16 points as required in Q7)
        points = []
        for i in range(16):
            points.append((i, i))
        return points

    def contains(self, x, y):
        raise NotImplementedError("Contains method not implemented")


# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        self.length = length
        self.width = width
        self.x = x
        self.y = y

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

    def contains(self, px, py):
        # Check if point is inside rectangle boundaries
        return (self.x <= px <= self.x + self.length and
                self.y <= py <= self.y + self.width)


# Circle class
class Circle(Shape):
    def __init__(self, radius, x, y):
        self.radius = radius
        self.x = x
        self.y = y

    def area(self):
        return math.pi * (self.radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.radius

    def contains(self, px, py):
        dx = px - self.x
        dy = py - self.y
        return (dx**2 + dy**2) <= (self.radius**2)


# Triangle class 
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        self.base = base
        self.height = height
        self.x = x
        self.y = y

    def area(self):
        return 0.5 * self.base * self.height

    def perimeter(self):
        side = ((self.base / 2)**2 + self.height**2) ** 0.5
        return self.base + 2 * side

    def contains(self, px, py):
        # Simple bounding check 
        return (self.x <= px <= self.x + self.base and
                self.y <= py <= self.y + self.height)


# CompoundShape class (group of shapes)
class CompoundShape(Shape):
    def __init__(self, shapes=None):
        # This shape stores a list of other shapes
        self.shapes = shapes if shapes is not None else []

    def add_shape(self, shape):
        # Adds a new shape to the compound object
        self.shapes.append(shape)

    def area(self):
        # Total area is the sum of all shapes 
        total = 0
        for s in self.shapes:
            total += s.area()
        return total

    def perimeter(self):
        # Simple sum of perimeters 
        total = 0
        for s in self.shapes:
            total += s.perimeter()
        return total


# Simple Canvas class 
class Canvas:
    def __init__(self):
        # Stores shapes that will be drawn
        self.objects = []

    def add(self, shape):
        # Add shape to canvas
        self.objects.append(shape)

    def paint(self):
        # For this lab, we will just print shape info instead of real graphics
        print("Painting canvas with the following shapes:")
        for obj in self.objects:
            print(type(obj).__name__, 
                  "| Area:", round(obj.area(), 2), 
                  "| Perimeter:", round(obj.perimeter(), 2))
# Out:
# Writing paint.py

# %%
# Test Cell

from paint import Rectangle, Circle, Triangle, CompoundShape, Canvas

# Create individual shapes
rect = Rectangle(4, 3, 0, 0)
circle = Circle(2, 5, 5)
tri = Triangle(6, 4, 2, 2)

# Create a compound shape (group of shapes)
compound = CompoundShape([rect, circle])
compound.add_shape(tri)

# Create canvas and add shapes
canvas = Canvas()
canvas.add(rect)
canvas.add(circle)
canvas.add(tri)
canvas.add(compound)

# Paint the canvas (demo output)
canvas.paint()
# Out:
# Painting canvas with the following shapes:
# Rectangle | Area: 12 | Perimeter: 14
# Circle | Area: 12.57 | Perimeter: 12.57
# Triangle | Area: 12.0 | Perimeter: 16.0
# CompoundShape | Area: 36.57 | Perimeter: 42.57

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
# Q11 - Solution Cell

from paint import Rectangle, Circle, Triangle, CompoundShape, Canvas

# Add some basic move/resize methods to shapes.

def rect_move(self, new_x, new_y):
    self.x = new_x
    self.y = new_y

def rect_resize(self, new_length, new_width):
    self.length = new_length
    self.width = new_width

Rectangle.move = rect_move
Rectangle.resize = rect_resize


def circle_move(self, new_x, new_y):
    self.x = new_x
    self.y = new_y

def circle_resize(self, new_radius):
    self.radius = new_radius

Circle.move = circle_move
Circle.resize = circle_resize


def tri_move(self, new_x, new_y):
    self.x = new_x
    self.y = new_y

def tri_resize(self, new_base, new_height):
    self.base = new_base
    self.height = new_height

Triangle.move = tri_move
Triangle.resize = tri_resize


# Add a couple helpful Canvas functions too
def canvas_remove(self, shape):
    # Remove the first matching shape (if it exists)
    if shape in self.objects:
        self.objects.remove(shape)

def canvas_clear(self):
    self.objects = []

Canvas.remove = canvas_remove
Canvas.clear = canvas_clear

# %%
# Test Cell

from paint import Rectangle, Circle, Triangle, CompoundShape, Canvas

# Step 1: Create shapes
rect = Rectangle(4, 3, 0, 0)
circle = Circle(2, 5, 5)
tri = Triangle(6, 4, 2, 2)

# Step 2: Make a compound shape (group)
compound = CompoundShape([rect, circle])

# Step 3: Add everything to a canvas
canvas = Canvas()
canvas.add(rect)
canvas.add(circle)
canvas.add(tri)
canvas.add(compound)

print("=== First paint (original drawing) ===")
canvas.paint()

# Step 4: Modify the drawing
# Move rectangle, shrink circle, resize triangle
rect.move(10, 1)
rect.resize(2, 2)

circle.move(1, 8)
circle.resize(1)

tri.move(6, 6)
tri.resize(3, 2)

# Also remove the triangle from the canvas just to show we can edit the objects list
canvas.remove(tri)

print("\n=== Second paint (after modifications) ===")
canvas.paint()
# Out:
# === First paint (original drawing) ===
# Painting canvas with the following shapes:
# Rectangle | Area: 12 | Perimeter: 14
# Circle | Area: 12.57 | Perimeter: 12.57
# Triangle | Area: 12.0 | Perimeter: 16.0
# CompoundShape | Area: 24.57 | Perimeter: 26.57
#
# === Second paint (after modifications) ===
# Painting canvas with the following shapes:
# Rectangle | Area: 4 | Perimeter: 8
# Circle | Area: 3.14 | Perimeter: 6.28
# CompoundShape | Area: 7.14 | Perimeter: 14.28

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %% [markdown]
# Solution Starts From Here:

# %%
# Q12 - Solution Cell

from paint import Rectangle, Circle, Triangle, CompoundShape

# Add __repr__ methods (so objects can be reconstructed)

def rect_repr(self):
    return f"Rectangle({self.length!r}, {self.width!r}, {self.x!r}, {self.y!r})"
Rectangle.__repr__ = rect_repr

def circle_repr(self):
    return f"Circle({self.radius!r}, {self.x!r}, {self.y!r})"
Circle.__repr__ = circle_repr

def tri_repr(self):
    return f"Triangle({self.base!r}, {self.height!r}, {self.x!r}, {self.y!r})"
Triangle.__repr__ = tri_repr

def comp_repr(self):
    # CompoundShape stores a list called shapes in the paint.py version
    return f"CompoundShape({self.shapes!r})"
CompoundShape.__repr__ = comp_repr


# RasterDrawing class with save/load
class RasterDrawing:
    def __init__(self, shapes=None):
        self.shapes = list(shapes) if shapes else []

    def add(self, shape):
        self.shapes.append(shape)

    def paint(self):
        # Using the same "print drawing" approach as earlier questions
        print("RasterDrawing contains these shapes:")
        for s in self.shapes:
            print(" ", repr(s))

    def __repr__(self):
        # This is the key part: return python code that rebuilds the drawing
        return f"RasterDrawing({self.shapes!r})"

    def save(self, filename):
        # Save the string returned by __repr__ into a file
        with open(filename, "w") as f:
            f.write(repr(self))

    @staticmethod
    def load(filename):
        # Load by reading the file then eval'ing the saved representation
        with open(filename, "r") as f:
            txt = f.read()

        env = {
            "RasterDrawing": RasterDrawing,
            "Rectangle": Rectangle,
            "Circle": Circle,
            "Triangle": Triangle,
            "CompoundShape": CompoundShape
        }
        return eval(txt, env)

# %%
# Test Cell

from paint import Rectangle, Circle, Triangle, CompoundShape

# Make some shapes
r = Rectangle(4, 3, 0, 0)
c = Circle(2, 5, 5)
t = Triangle(6, 4, 2, 2)

# Make a compound shape too
comp = CompoundShape([r, c])

# Make a raster drawing and add shapes
drawing = RasterDrawing([r, c, t, comp])

print("Repr of drawing:")
print(repr(drawing))

# Save
drawing.save("my_drawing.txt")

print("\nSaved file contents:")
with open("my_drawing.txt", "r") as f:
    print(f.read())

# Load
loaded = RasterDrawing.load("my_drawing.txt")

print("\nLoaded drawing repr:")
print(repr(loaded))

print("\nLoaded drawing paint():")
loaded.paint()
# Out:
# Repr of drawing:
# RasterDrawing([Rectangle(4, 3, 0, 0), Circle(2, 5, 5), Triangle(6, 4, 2, 2), CompoundShape([Rectangle(4, 3, 0, 0), Circle(2, 5, 5)])])
#
# Saved file contents:
# RasterDrawing([Rectangle(4, 3, 0, 0), Circle(2, 5, 5), Triangle(6, 4, 2, 2), CompoundShape([Rectangle(4, 3, 0, 0), Circle(2, 5, 5)])])
#
# Loaded drawing repr:
# RasterDrawing([Rectangle(4, 3, 0, 0), Circle(2, 5, 5), Triangle(6, 4, 2, 2), CompoundShape([Rectangle(4, 3, 0, 0), Circle(2, 5, 5)])])
#
# Loaded drawing paint():
# RasterDrawing contains these shapes:
#   Rectangle(4, 3, 0, 0)
#   Circle(2, 5, 5)
#   Triangle(6, 4, 2, 2)
#   CompoundShape([Rectangle(4, 3, 0, 0), Circle(2, 5, 5)])
